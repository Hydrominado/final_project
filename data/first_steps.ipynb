# %% [markdown]
# # Projet Fil Rouge
# ### Nom, Prénom, Année

# %% [markdown]
# ## Data Cleaning

# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-macosx_10_9_x86_64.whl (12.6 MB)
#      |████████████████████████████████| 12.6 MB 9.7 MB/s eta 0:00:01     |██████████████████████████      | 10.2 MB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/angelinebasil/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting numpy>=1.22.4
#   Downloading numpy-2.0.1-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#      |████████████████████████████████| 21.2 MB 26.7 MB/s eta 0:00:01     |██████████████████████████      | 17.3 MB 26.7 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 38.7 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 36.2 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-2.0.1 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
df = pd.read_csv ('tripadvisor_european_restaurants.csv')
# Out:
# /var/folders/jr/skm14yw54w99224r0y3n7zzc0000gn/T/ipykernel_2125/3683973478.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv ('tripadvisor_european_restaurants.csv')

# %%
df.head().T
# Out:
#                                                                                    0  \
# restaurant_link                                                  g10001637-d10002227
# restaurant_name                                                               Le 147
# original_location                  ["Europe", "France", "Nouvelle-Aquitaine", "Ha...
# country                                                                       France
# region                                                            Nouvelle-Aquitaine
# province                                                                Haute-Vienne
# city                                                                   Saint-Jouvent
# address                                  10 Maison Neuve, 87510 Saint-Jouvent France
# latitude                                                                   45.961674
# longitude                                                                   1.169131
# claimed                                                                      Claimed
# awards                                                                           NaN
# popularity_detailed                             #1 of 2 Restaurants in Saint-Jouvent
# popularity_generic                            #1 of 2 places to eat in Saint-Jouvent
# top_tags                                                          Cheap Eats, French
# price_level                                                                        €
# price_range                                                                      NaN
# meals                                                                  Lunch, Dinner
# cuisines                                                                      French
# special_diets                                                                    NaN
# features                           Reservations, Seating, Wheelchair Accessible, ...
# vegetarian_friendly                                                                N
# vegan_options                                                                      N
# gluten_free                                                                        N
# original_open_hours                                                              NaN
# open_days_per_week                                                               NaN
# open_hours_per_week                                                              NaN
# working_shifts_per_week                                                          NaN
# avg_rating                                                                       4.0
# total_reviews_count                                                             36.0
# default_language                                                             English
# reviews_count_in_default_language                                                2.0
# excellent                                                                        2.0
# very_good                                                                        0.0
# average                                                                          0.0
# poor                                                                             0.0
# terrible                                                                         0.0
# food                                                                             4.0
# service                                                                          4.5
# value                                                                            4.0
# atmosphere                                                                       NaN
# keywords                                                                         NaN
#
#                                                                                    1  \
# restaurant_link                                                  g10001637-d14975787
# restaurant_name                                                     Le Saint Jouvent
# original_location                  ["Europe", "France", "Nouvelle-Aquitaine", "Ha...
# country                                                                       France
# region                                                            Nouvelle-Aquitaine
# province                                                                Haute-Vienne
# city                                                                   Saint-Jouvent
# address                             16 Place de l Eglise, 87510 Saint-Jouvent France
# latitude                                                                    45.95704
# longitude                                                                    1.20548
# claimed                                                                    Unclaimed
# awards                                                                           NaN
# popularity_detailed                             #2 of 2 Restaurants in Saint-Jouvent
# popularity_generic                            #2 of 2 places to eat in Saint-Jouvent
# top_tags                                                                  Cheap Eats
# price_level                                                                        €
# price_range                                                                      NaN
# meals                                                                            NaN
# cuisines                                                                         NaN
# special_diets                                                                    NaN
# features                                                                         NaN
# vegetarian_friendly                                                                N
# vegan_options                                                                      N
# gluten_free                                                                        N
# original_open_hours                                                              NaN
# open_days_per_week                                                               NaN
# open_hours_per_week                                                              NaN
# working_shifts_per_week                                                          NaN
# avg_rating                                                                       4.0
# total_reviews_count                                                              5.0
# default_language                                                       All languages
# reviews_count_in_default_language                                                5.0
# excellent                                                                        2.0
# very_good                                                                        2.0
# average                                                                          1.0
# poor                                                                             0.0
# terrible                                                                         0.0
# food                                                                             NaN
# service                                                                          NaN
# value                                                                            NaN
# atmosphere                                                                       NaN
# keywords                                                                         NaN
#
#                                                                                    2  \
# restaurant_link                                                   g10002858-d4586832
# restaurant_name                                                      Au Bout du Pont
# original_location                  ["Europe", "France", "Centre-Val de Loire", "B...
# country                                                                       France
# region                                                           Centre-Val de Loire
# province                                                                       Berry
# city                                                                      Rivarennes
# address                                     2 rue des Dames, 36800 Rivarennes France
# latitude                                                                   46.635895
# longitude                                                                   1.386133
# claimed                                                                      Claimed
# awards                                                                           NaN
# popularity_detailed                                 #1 of 1 Restaurant in Rivarennes
# popularity_generic                               #1 of 1 places to eat in Rivarennes
# top_tags                                                Cheap Eats, French, European
# price_level                                                                        €
# price_range                                                                      NaN
# meals                                                          Dinner, Lunch, Drinks
# cuisines                                                            French, European
# special_diets                                                                    NaN
# features                           Reservations, Seating, Table Service, Wheelcha...
# vegetarian_friendly                                                                N
# vegan_options                                                                      N
# gluten_free                                                                        N
# original_open_hours                                                              NaN
# open_days_per_week                                                               NaN
# open_hours_per_week                                                              NaN
# working_shifts_per_week                                                          NaN
# avg_rating                                                                       5.0
# total_reviews_count                                                             13.0
# default_language                                                             English
# reviews_count_in_default_language                                                4.0
# excellent                                                                        3.0
# very_good                                                                        1.0
# average                                                                          0.0
# poor                                                                             0.0
# terrible                                                                         0.0
# food                                                                             NaN
# service                                                                          NaN
# value                                                                            NaN
# atmosphere                                                                       NaN
# keywords                                                                         NaN
#
#                                                                                    3  \
# restaurant_link                                                   g10002986-d3510044
# restaurant_name                                                  Le Relais de Naiade
# original_location                  ["Europe", "France", "Nouvelle-Aquitaine", "Co...
# country                                                                       France
# region                                                            Nouvelle-Aquitaine
# province                                                                     Correze
# city                                                                         Lacelle
# address                            9 avenue Porte de la Correze 19170, 19170 Lace...
# latitude                                                                    45.64261
# longitude                                                                    1.82446
# claimed                                                                      Claimed
# awards                                                                           NaN
# popularity_detailed                                    #1 of 1 Restaurant in Lacelle
# popularity_generic                                  #1 of 1 places to eat in Lacelle
# top_tags                                                          Cheap Eats, French
# price_level                                                                        €
# price_range                                                                      NaN
# meals                                                                  Lunch, Dinner
# cuisines                                                                      French
# special_diets                                                                    NaN
# features                           Reservations, Seating, Serves Alcohol, Table S...
# vegetarian_friendly                                                                N
# vegan_options                                                                      N
# gluten_free                                                                        N
# original_open_hours                                                              NaN
# open_days_per_week                                                               NaN
# open_hours_per_week                                                              NaN
# working_shifts_per_week                                                          NaN
# avg_rating                                                                       4.0
# total_reviews_count                                                             34.0
# default_language                                                             English
# reviews_count_in_default_language                                                1.0
# excellent                                                                        1.0
# very_good                                                                        0.0
# average                                                                          0.0
# poor                                                                             0.0
# terrible                                                                         0.0
# food                                                                             4.5
# service                                                                          4.5
# value                                                                            4.5
# atmosphere                                                                       NaN
# keywords                                                                         NaN
#
#                                                                                    4
# restaurant_link                                                   g10022428-d9767191
# restaurant_name                                                 Relais Du MontSeigne
# original_location                  ["Europe", "France", "Occitanie", "Aveyron", "...
# country                                                                       France
# region                                                                     Occitanie
# province                                                                     Aveyron
# city                                                        Saint-Laurent-de-Levezou
# address                            route du Montseigne, 12620 Saint-Laurent-de-Le...
# latitude                                                                    44.20886
# longitude                                                                    2.96047
# claimed                                                                    Unclaimed
# awards                                                                           NaN
# popularity_detailed                   #1 of 1 Restaurant in Saint-Laurent-de-Levezou
# popularity_generic                 #1 of 1 places to eat in Saint-Laurent-de-Levezou
# top_tags                                                           Mid-range, French
# price_level                                                                   €€-€€€
# price_range                                                                      NaN
# meals                                                                  Lunch, Dinner
# cuisines                                                                      French
# special_diets                                                                    NaN
# features                           Reservations, Seating, Wheelchair Accessible, ...
# vegetarian_friendly                                                                N
# vegan_options                                                                      N
# gluten_free                                                                        N
# original_open_hours                                                              NaN
# open_days_per_week                                                               NaN
# open_hours_per_week                                                              NaN
# working_shifts_per_week                                                          NaN
# avg_rating                                                                       4.5
# total_reviews_count                                                             11.0
# default_language                                                       All languages
# reviews_count_in_default_language                                               11.0
# excellent                                                                        4.0
# very_good                                                                        7.0
# average                                                                          0.0
# poor                                                                             0.0
# terrible                                                                         0.0
# food                                                                             4.5
# service                                                                          4.5
# value                                                                            4.5
# atmosphere                                                                       NaN
# keywords                                                                         NaN

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083397 entries, 0 to 1083396
# Data columns (total 42 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   restaurant_link                    1083397 non-null  object
#  1   restaurant_name                    1083396 non-null  object
#  2   original_location                  1083397 non-null  object
#  3   country                            1083397 non-null  object
#  4   region                             1033074 non-null  object
#  5   province                           742765 non-null   object
#  6   city                               682712 non-null   object
#  7   address                            1083397 non-null  object
#  8   latitude                           1067607 non-null  float64
#  9   longitude                          1067607 non-null  float64
#  10  claimed                            1081555 non-null  object
#  11  awards                             263133 non-null   object
#  12  popularity_detailed                988409 non-null   object
#  13  popularity_generic                 985605 non-null   object
#  14  top_tags                           972763 non-null   object
#  15  price_level                        806192 non-null   object
#  16  price_range                        304327 non-null   object
#  17  meals                              635347 non-null   object
#  18  cuisines                           914294 non-null   object
#  19  special_diets                      340256 non-null   object
#  20  features                           317407 non-null   object
#  21  vegetarian_friendly                1083397 non-null  object
#  22  vegan_options                      1083397 non-null  object
#  23  gluten_free                        1083397 non-null  object
#  24  original_open_hours                593832 non-null   object
#  25  open_days_per_week                 593832 non-null   float64
#  26  open_hours_per_week                593832 non-null   float64
#  27  working_shifts_per_week            593832 non-null   float64
#  28  avg_rating                         986761 non-null   float64
#  29  total_reviews_count                1031162 non-null  float64
#  30  default_language                   988204 non-null   object
#  31  reviews_count_in_default_language  988204 non-null   float64
#  32  excellent                          988204 non-null   float64
#  33  very_good                          988204 non-null   float64
#  34  average                            988204 non-null   float64
#  35  poor                               988204 non-null   float64
#  36  terrible                           988204 non-null   float64
#  37  food                               599325 non-null   float64
#  38  service                            604287 non-null   float64
#  39  value                              602692 non-null   float64
#  40  atmosphere                         261785 non-null   float64
#  41  keywords                           99198 non-null    object
# dtypes: float64(17), object(25)
# memory usage: 347.2+ MB

# %% [markdown]
# ## Data Visualisation
# Ici, vous réaliserez vos observations, créerez vos graphes dans un premier temps. Une fois qu'ils seront fait, ils seront à intégrer à votre application Streamlit. Considérez donc cet espace comme un bac à sable avant de vous lancer dans le développement de l'application de Data Visualisation.

# %%
# Ici, vous réaliserez la visualisation de votre jeu de données
